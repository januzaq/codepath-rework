# %% [markdown]
# <a href="https://colab.research.google.com/github/januzaq/codepath-rework/blob/main/spis26_lab00_%3CZhanuzak%3E_%3CU%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Zhan Ulankalyi SPIS 2026
print('Hello, World!')
print('Hello, you!')
# Out:
# Hello, World!
# Hello, you!
